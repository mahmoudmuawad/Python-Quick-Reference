# %% [markdown]
# # Matplotlib
# Matplotlib is the "grandfather" library of data visualization with Python. It was created by John Hunter. He created it to try to replicate MatLab's (another programming language) plotting capabilities in Python.

# %%
import matplotlib.pyplot as plt            # importing                        #show figures inside notebook
plt.style.use('ggplot')                    # style

# %% [markdown]
# ## Basic commans on arrays

# %%
# %matplotlib inline 
import numpy as np
x = np.linspace(0,8,15)
y = x**2
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title("simple command")

# %% [markdown]
# ### - holding all

# %%
def f(x):
    return 1/(1+ np.exp(-x))
x = np.arange(-5, 5, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)
sig_y = f(x)
plt.plot(x, sin_y, color='red', linewidth=2.5, linestyle='--')
plt.plot(x, cos_y, color='blue', linewidth=2.5, linestyle='-')
plt.plot(x, sig_y, color='green', linewidth=2.5, linestyle='-.')

plt.title("sin vs cos wave from -5 to 5")
plt.grid(True)
plt.xlabel("time")
plt.ylabel("amplitude")
plt.show()

# %% [markdown]
# ### - Bar

# %%
objects = ('Python', 'C++', 'Java', 'Perl', 'Scala', 'Lisp')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]
 
plt.bar(y_pos, performance)
plt.xticks(y_pos, objects)
plt.ylabel('Usage')
plt.title('Programming language usage')
 
plt.show()

# %% [markdown]
# ### - Bars Comparing

# %%
# data to plot
ahmed = [0, 12, 3, 9]
mona = [2, 8, 6, 6]
factors = ['kitchen', 'sleep', 'tv', 'playing']
 
# create plot
index = np.arange(len(factors))
 
rects1 = plt.bar(index, ahmed,
                 color='b',
                 label='Ahmed')
 
rects2 = plt.bar(index, mona,
                 color='r',
                 label='Mona')
 
plt.xlabel('Person')
plt.ylabel('Time Spent')
plt.title('Time spent')
plt.xticks(index , factors)
plt.legend()
plt.show()

# %%
# data to plot
ahmed = [0, 12, 3, 9]
mona = [2, 8, 6, 6]
factors = ['kitchen', 'sleep', 'tv', 'playing']
col_width = 0.35
 
# create plot
index = np.arange(len(factors))
 
rects1 = plt.bar(index, ahmed, col_width,
                 color='b',
                 label='Ahmed')
 
rects2 = plt.bar(index+col_width, mona, col_width,
                 color='r',
                 label='Mona')
 
plt.xlabel('Person')
plt.ylabel('Time Spent')
plt.title('Time spent')
plt.xticks(index+col_width/2 , factors)
plt.legend()
plt.show()

# %% [markdown]
# ### - Pie plot

# %%
# Data to plot
labels = 'Python', 'C++', 'Ruby', 'Java'
sizes = [230, 200, 150, 250]
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels,
        autopct='%1.2f%%', shadow=True)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# ### - Histogram

# %%
# arbitary example
y = [0, 0, 0, 1, 1, 1,2 , 3, 2, 5, 1, 4, 3, 3, 4, 4]

plt.hist(y)
plt.show()

# %% [markdown]
# ### - Heat Map

# %%
m = [
[1,0,2,0,2],
[1,1,1,2,5],
[0,4,1,0,0],
[0,4,4,1,2],
[1,3,0,0,1],
]

plt.matshow(m)

groups = ['Blues','Jazz','Rock','House','Dance']
x_pos = np.arange(len(groups))
plt.xticks(x_pos,groups)
 
y_pos = np.arange(len(groups))
plt.yticks(y_pos,groups)
 
plt.show();

# %% [markdown]
# ## Matplotlib Object Oriented Method
# Now that we've seen the basics, let's break it all down with a more formal introduction of Matplotlib's Object Oriented API. This means we will instantiate figure objects and then call methods or attributes from that object.

# %%
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.8,0.8])   # padding  : left, bottom, width, height (range 0 to 1)
# Plot on that set of axes
axes.plot(x, y, 'b')
axes.set_xlabel('Set X Label') # Notice the use of set_ to begin methods
axes.set_ylabel('Set y Label')
axes.set_title('Set Title')

# %%
## different scale in the same figure
fig = plt.figure()

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # main axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # inset axes
# Larger Figure Axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %% [markdown]
# ## Multiple plots in the same figure

# %%
# plt.plot(n_raws, n_cols, plot number)
plt.subplot(1,2,1)
plt.plot(x,y,'r-')
plt.subplot(1,2,2)
plt.plot(x,y,'b*-')

# %% [markdown]
# ## Figure size and aspect ratio
# Matplotlib allows the aspect ratio, DPI and figure size to be specified when the Figure object is created. You can use the figsize and dpi keyword arguments.
# figsize  : is a tuple of the width and height of the figure in inchesd .
# pi      : is the dots-per-inch (pixel per inch).

# %%
fig = plt.figure(figsize=(4,4), dpi=100)

# %% [markdown]
# ## saving figures
# Matplotlib can generate high-quality output in a number formats, including PNG, JPG, EPS, SVG, PGF and PDF.

# %%
fig.savefig("filename.png")

# %% [markdown]
# ## Legends, labels and titles

# %%
axes.set_title("title");    # setting the title
axes.set_xlabel("x")        # labels    
axes.set_ylabel("y")        # labels
axes.legend()               # legend

# %% [markdown]
# ## Line and marker styles

# %%
axes.plot(x, x+1, color="red", linewidth=0.25)
axes.plot(x, x+2, color="red", linewidth=0.50)
axes.plot(x, x+3, color="red", linewidth=1.00)
axes.plot(x, x+4, color="red", lw=1, ls='-', marker='o', markersize=2) 
# where ls : style, lw : line width, marker ,

# %% [markdown]
# ## Special Plots

# %%
# point plot
plt.scatter(x,y)

# %%
from random import sample
data = sample(range(1, 1000), 100)
plt.hist(data)          # plotting frequancy
# Out:
# (array([14., 10., 13., 10.,  6.,  9., 11.,  7., 15.,  5.]),
#  array([ 10. , 108.3, 206.6, 304.9, 403.2, 501.5, 599.8, 698.1, 796.4,
#         894.7, 993. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Advanced Matplotlib

# %% [markdown]
# ## Placement of ticks and custom tick labels

# %%
fig, ax = plt.subplots(figsize=(10, 4))

ax.plot(x, x**2, x, x**3, lw=2)

ax.set_xticks([1, 2, 3, 4, 5])
ax.set_xticklabels([r'$\alpha$', r'$\beta$', r'$\gamma$', r'$\delta$', r'$\epsilon$'], fontsize=18)

yticks = [0, 50, 100, 150]
ax.set_yticks(yticks)
ax.set_yticklabels(["$%.1f$" % y for y in yticks], fontsize=18); # use LaTeX formatted labels

ax.grid(True) # grid

# %% [markdown]
# ## Axes where x and y is zero

# %%
fig, ax = plt.subplots()

ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0)) # set position of x spine to x=0

ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))   # set position of y spine to y=0

xx = np.linspace(-0.75, 1., 100)
ax.plot(xx, xx**3);

# %% [markdown]
# ## Other 2d plot styles

# %% [markdown]
# ### - step,bar and fill plot

# %%
n = np.array([0,1,2,3,4,5])
fig, axes = plt.subplots(1, 3, figsize=(12,3))

axes[0].step(n, n**2, lw=2)
axes[0].set_title("step")

axes[1].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[1].set_title("bar")

axes[2].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[2].set_title("fill_between");

# %% [markdown]
# ### - Text annotation

# %%
fig, ax = plt.subplots()

ax.plot(xx, xx**2, xx, xx**3)

ax.text(0.15, 0.2, r"$y=x^2$", fontsize=20, color="blue")
ax.text(0.65, 0.1, r"$y=x^3$", fontsize=20, color="green");

# %% [markdown]
# ## Clolor Map and Contour Plots

# %%
# the used Parameters
alpha = 0.7
phi_ext = 2 * np.pi * 0.5

def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
# range and meshgrid
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %%
# P-plot
fig, ax = plt.subplots()

p = ax.pcolor(X/(2*np.pi), Y/(2*np.pi), Z, cmap=plt.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max())
cb = fig.colorbar(p, ax=ax)

# %%
# imshow
fig, ax = plt.subplots()

im = ax.imshow(Z, cmap=plt.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max(), extent=[0, 1, 0, 1])
im.set_interpolation('bilinear')

cb = fig.colorbar(im, ax=ax)

# %%
# Contour
fig, ax = plt.subplots()

cnt = ax.contour(Z, cmap=plt.cm.RdBu, vmin=abs(Z).min(), vmax=abs(Z).max(), extent=[0, 1, 0, 1])

# %% [markdown]
# # 3d Plots
# To use 3D graphics in matplotlib, we first need to create an instance of the Axes3D class. 3D axes can be added to a matplotlib figure canvas in exactly the same way as 2D axes; or, more conveniently, by passing a projection='3d' keyword argument to the add_axes or add_subplot methods.

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D      # importing Axes3D class

# %% [markdown]
# ### - Surface Plots

# %%
fig = plt.figure(figsize=(14,6))

# `ax` is a 3D-aware axis instance because of the projection='3d' keyword argument to add_subplot
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# surface_plot with color grading and color bar
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap=plt.cm.coolwarm, linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %% [markdown]
# ## - Coutour plots with projections

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
cset = ax.contour(X, Y, Z, zdir='z', offset=-np.pi, cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-np.pi, cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*np.pi, cmap=plt.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);
